# %% [markdown]
# # EDA
# - price 상한가 37억, 11억만 삭제
# - 하한가만 조정
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import rankdata

# %%
df = pd.read_csv('vehicles_processed.csv')

# %% [markdown]
# - describe은 제외하도록 함

# %% [markdown]
# ## 범주형 데이터 컬럼 분석
# - manufacturer
# - model
# - condition
# - cylinders
# - fuel
# - transmission
# - drive
# - type
# - paint_color

# %%
def show_categorical(df, col):
    cate = df[col].value_counts()
    cate = pd.DataFrame(cate)
    cate.reset_index(inplace=True)
    
    cate = cate.sort_values('count',ascending=False)
    print("========== [ INFO ] ==========")
    print("Column: ", col)
    print("Number of unique values: ", len(cate))
    print("Max value: ", cate['count'].max())
    print("Min value: ", cate['count'].min())
    print("Mean value: ", cate['count'].mean())
    print("Median value: ", cate['count'].median()) 
    print("25% percentile: ", cate['count'].quantile(0.25))
    print("75% percentile: ", cate['count'].quantile(0.75))
    
    if len(cate) > 20:
        df_set = df[col].value_counts()[:20]
        plt.figure(figsize=(20, 6))
        plt.title('Top 20 ' + col)
        plt.bar(df_set.index, df_set.values)
    else:
        df_set = df[col].value_counts()
        plt.figure(figsize=(20, 6))
        plt.title(col)
        plt.bar(df_set.index, df_set.values)
    plt.show()

# %%
cate_col = ['manufacturer', 'model', 'condition', 'cylinders', 'fuel', 'transmission', 'drive', 'type', 'paint_color']
for col in cate_col:
    
    show_categorical(df, col)
# Out:
# ========== [ INFO ] ==========
# Column:  manufacturer
# Number of unique values:  41
# Max value:  20743
# Min value:  5
# Mean value:  2828.9756097560976
# Median value:  1348.0
# 25% percentile:  420.0
# 75% percentile:  2922.0
# ========== [ INFO ] ==========
# Column:  model
# Number of unique values:  11529
# Max value:  1872
# Min value:  1
# Mean value:  10.060542978575766
# Median value:  2.0
# 25% percentile:  1.0
# 75% percentile:  4.0
# ========== [ INFO ] ==========
# Column:  condition
# Number of unique values:  6
# Max value:  52253
# Min value:  296
# Mean value:  19331.333333333332
# Median value:  8143.0
# 25% percentile:  1392.25
# 75% percentile:  38044.0
# ========== [ INFO ] ==========
# Column:  cylinders
# Number of unique values:  8
# Max value:  43101
# Min value:  60
# Mean value:  14498.5
# Median value:  899.0
# 25% percentile:  284.75
# 75% percentile:  34987.0
# ========== [ INFO ] ==========
# Column:  fuel
# Number of unique values:  5
# Max value:  106184
# Min value:  193
# Mean value:  23197.6
# Median value:  1882.0
# 25% percentile:  1319.0
# 75% percentile:  6410.0
# ========== [ INFO ] ==========
# Column:  transmission
# Number of unique values:  3
# Max value:  95511
# Min value:  8184
# Mean value:  38662.666666666664
# Median value:  12293.0
# 25% percentile:  10238.5
# 75% percentile:  53902.0
# ========== [ INFO ] ==========
# Column:  drive
# Number of unique values:  3
# Max value:  49082
# Min value:  27293
# Mean value:  38662.666666666664
# Median value:  39613.0
# 25% percentile:  33453.0
# 75% percentile:  44347.5
# ========== [ INFO ] ==========
# Column:  type
# Number of unique values:  13
# Max value:  30951
# Min value:  175
# Mean value:  8922.153846153846
# Median value:  3431.0
# 25% percentile:  3030.0
# 75% percentile:  12818.0
# ========== [ INFO ] ==========
# Column:  paint_color
# Number of unique values:  12
# Max value:  28061
# Min value:  342
# Mean value:  9665.666666666666
# Median value:  8030.0
# 25% percentile:  2149.25
# 75% percentile:  13655.5

# %% [markdown]
# ## 연속형 데이터 컬럼 분석
# - price
# - odometer
# - year

# %%
def show_series(df, col):
    cate = df[col]
    print("========== [ INFO ] ==========")
    print("Column: ", col)
    print("Number of unique values: ", len(cate))
    print("Max value: ", cate.max())
    print("Min value: ", cate.min())
    print("Mean value: ", cate.mean())
    print("Median value: ", cate.median()) 
    print("25% percentile: ", cate.quantile(0.25))
    print("75% percentile: ", cate.quantile(0.75))
    plt.figure(figsize=(6, 15))
    sns.boxplot(df[col])

# %%
show_series(df, 'price')
# Out:
# ========== [ INFO ] ==========
# Column:  price
# Number of unique values:  115988
# Max value:  3736928711
# Min value:  0
# Mean value:  60673.74454253889
# Median value:  10995.0
# 25% percentile:  5739.75
# 75% percentile:  22900.0

# %%
show_series(df, 'odometer')
# Out:
# ========== [ INFO ] ==========
# Column:  odometer
# Number of unique values:  115988
# Max value:  10000000.0
# Min value:  0.0
# Mean value:  111928.37270234851
# Median value:  102725.0
# 25% percentile:  55630.0
# 75% percentile:  147662.0

# %% [markdown]
# # Data Cleaning
# - price, odometer 0인 항목은 삭제하도록 함
# - odometer는 전체 데이터 셋에서의 quartile whisker 내부 항목만 분석 대상으로 함
# - 가격대의 경우, 제조사별로 percentile 0~100% 내부의 항목만 분석대상으로 함
#     - 100 달러 미만은 기본적으로 삭제함
#     - 페라리, 애스턴 마틴과 같은 고급 브랜드의 경우, 전 데이터셋에 대한 쿼타일 분석 시, 해당 브랜드의 모든 모델의 가격대가 이상치로 나타나기 때문임

# %%
# 0인 수치 데이터 모두 제외
df = df[df['price'] > 0]
df = df[df['odometer'] > 0]

df.reset_index(drop=True, inplace=True)

# %%
# 카테고리 항목 정리 -> 현저히 낮은 수치로 나타나는 값들은 모두 기타로 묶음

df['paint_color'].replace(['red', 'blue', 'white', 'brown', 'grey',
       'yellow', 'green', 'custom', 'purple', 'orange'], 'other', inplace=True)
df['cylinders'].replace(['5 cylinders',
       '10 cylinders', '3 cylinders', 'other', '12 cylinders'], 'other', inplace=True)
df['transmission'].replace(['other', 'manual'], 'other', inplace=True)
df['fuel'].replace(['electric','hybrid','diesel'], 'other', inplace=True)

# %% [markdown]
# ### odometer 정제
#
# - whisker 내부 데이터만 택함

# %%
q_75 = df['odometer'].quantile(0.75)
q_25 = df['odometer'].quantile(0.25)
IQR = q_75 - q_25
upper_bound = q_25 + 1.5*IQR
lower_bound = q_75 - 1.5*IQR
print("Quantile 75: ", q_75)
print("Quantile 25: ", q_25)
print("IQR: ", IQR)
print("Upper bound: ", upper_bound) 
print("Lower bound: ", lower_bound)

cleaned_1 = df[(df['odometer'] <= upper_bound)&(df['odometer'] >= lower_bound)]
cleaned_1.reset_index(inplace= True, drop = True)
cleaned_1
# Out:
# Quantile 75:  148577.0
# Quantile 25:  56344.0
# IQR:  92233.0
# Upper bound:  194693.5
# Lower bound:  10227.5
#                id  price    year manufacturer                        model  \
# 0      7316356412  15000  2013.0         ford                    f-150 xlt
# 1      7316343444  27990  2012.0          gmc  sierra 2500 hd extended cab
# 2      7316304717  34590  2016.0    chevrolet        silverado 1500 double
# 3      7316285779  35000  2019.0       toyota                       tacoma
# 4      7316257769  29990  2016.0    chevrolet        colorado extended cab
# ...           ...    ...     ...          ...                          ...
# 96454  7301954392  41990  2019.0       toyota        4runner limited sport
# 96455  7301951544  39990  2017.0     infiniti        qx80 sport utility 4d
# 96456  7301949190  32990  2016.0     infiniti        qx80 sport utility 4d
# 96457  7301591199  33590  2018.0        lexus              gs 350 sedan 4d
# 96458  7301591140  28990  2018.0        lexus              es 350 sedan 4d
#
#        condition    cylinders fuel  odometer transmission drive    type  \
# 0      excellent  6 cylinders  gas  128000.0    automatic   rwd   truck
# 1           good  8 cylinders  gas   68696.0        other   4wd  pickup
# 2           good  6 cylinders  gas   29499.0        other   4wd  pickup
# 3      excellent  6 cylinders  gas   43000.0    automatic   4wd   truck
# 4           good  6 cylinders  gas   17302.0        other   4wd  pickup
# ...          ...          ...  ...       ...          ...   ...     ...
# 96454       good  6 cylinders  gas   36630.0        other   4wd     SUV
# 96455       good  8 cylinders  gas   41664.0    automatic   4wd   other
# 96456       good  8 cylinders  gas   55612.0    automatic   rwd   other
# 96457       good  6 cylinders  gas   30814.0    automatic   rwd   sedan
# 96458       good  6 cylinders  gas   30112.0        other   fwd   sedan
#
#       paint_color
# 0           black
# 1           black
# 2          silver
# 3           other
# 4           other
# ...           ...
# 96454       other
# 96455       black
# 96456       black
# 96457       other
# 96458      silver
#
# [96459 rows x 13 columns]

# %%
show_series(cleaned_1, 'odometer')
# Out:
# ========== [ INFO ] ==========
# Column:  odometer
# Number of unique values:  96459
# Max value:  194681.0
# Min value:  10230.0
# Mean value:  98437.3104531459
# Median value:  100000.0
# 25% percentile:  58867.0
# 75% percentile:  137000.0

# %% [markdown]
# ### price 정제
# - 하한선은 quantile 25% 부터

# %%
def clean_price(data):
    mans = data['manufacturer'].unique().tolist()
    data = data.groupby(['manufacturer','model','id']).sum()
    data.reset_index(inplace=True)
    new_df = []
    for man in mans:
        targ = data[data['manufacturer'] == man]
        targ.reset_index(inplace=True, drop = True)
        q_25 = targ['price'].quantile(0.25)
        q_75 = targ['price'].quantile(0.75)
        IQR = q_75 - q_25
        upper_bound = q_25+1.5*IQR
        lower_bound = q_25
        
        print("=== [%s] ==="%man)
        print("Number of : ", len(targ))
        print("Quantile 75: ", q_75)
        print("Quantile 25: ", q_25)
        print("IQR: ", IQR)
        print("Upper bound: ", upper_bound) 
        print("Lower bound: ", lower_bound)
        print("Max: ", targ['price'].max())
        print("Min: ", targ['price'].min())
        print("Mean: ", targ['price'].mean())
        print("Median: ", targ['price'].median())
        
        targ = targ[(targ['price'] <= upper_bound)&(targ['price'] >= lower_bound)]
        targ.reset_index(inplace= True, drop = True)
        new_df.append(targ)
        
    new_df = pd.concat(new_df)
    new_df.reset_index(inplace= True, drop = True) 
    return new_df

cleaned_2 = clean_price(cleaned_1)
cleaned_2
# Out:
# === [ford] ===
# Number of :  16664
# Quantile 75:  26990.0
# Quantile 25:  7495.0
# IQR:  19495.0
# Upper bound:  36737.5
# Lower bound:  7495.0
# Max:  1111111111
# Min:  1
# Mean:  84814.81661065771
# Median:  13995.0
# === [gmc] ===
# Number of :  3957
# Quantile 75:  34990.0
# Quantile 25:  12500.0
# IQR:  22490.0
# Upper bound:  46235.0
# Lower bound:  12500.0
# Max:  90000
# Min:  1
# Mean:  24493.261056355826
# Median:  24990.0
# === [chevrolet] ===
# Number of :  14382
# Quantile 75:  28900.0
# Quantile 25:  7500.0
# IQR:  21400.0
# Upper bound:  39600.0
# Lower bound:  7500.0
# Max:  125000
# Min:  1
# Mean:  18681.039702405786
# Median:  15000.0
# === [toyota] ===
# Number of :  7716
# Quantile 75:  22000.0
# Quantile 25:  6700.0
# IQR:  15300.0
# Upper bound:  29650.0
# Lower bound:  6700.0
# Max:  3736928711
# Min:  1
# Mean:  499824.0964230171
# Median:  11500.0
# === [jeep] ===
# Number of :  4947
# Quantile 75:  28682.5
# Quantile 25:  8261.0
# IQR:  20421.5
# Upper bound:  38893.25
# Lower bound:  8261.0
# Max:  1234567
# Min:  1
# Mean:  19258.92803719426
# Median:  17450.0
# === [nissan] ===
# Number of :  5310
# Quantile 75:  16900.0
# Quantile 25:  5995.0
# IQR:  10905.0
# Upper bound:  22352.5
# Lower bound:  5995.0
# Max:  135008900
# Min:  1
# Mean:  37625.91111111111
# Median:  9500.0
# === [honda] ===
# Number of :  5334
# Quantile 75:  12995.0
# Quantile 25:  5500.0
# IQR:  7495.0
# Upper bound:  16742.5
# Lower bound:  5500.0
# Max:  50000
# Min:  1
# Mean:  9961.557180352456
# Median:  8500.0
# === [dodge] ===
# Number of :  3336
# Quantile 75:  20900.0
# Quantile 25:  5968.75
# IQR:  14931.25
# Upper bound:  28365.625
# Lower bound:  5968.75
# Max:  1111111
# Min:  1
# Mean:  14567.639988009592
# Median:  9995.0
# === [chrysler] ===
# Number of :  1825
# Quantile 75:  12795.0
# Quantile 25:  4500.0
# IQR:  8295.0
# Upper bound:  16942.5
# Lower bound:  4500.0
# Max:  86000
# Min:  1
# Mean:  9589.179726027398
# Median:  7500.0
# === [ram] ===
# Number of :  3369
# Quantile 75:  35990.0
# Quantile 25:  16900.0
# IQR:  19090.0
# Upper bound:  45535.0
# Lower bound:  16900.0
# Max:  17000000
# Min:  1
# Mean:  32441.32235084595
# Median:  29895.0
# === [mercedes-benz] ===
# Number of :  2660
# Quantile 75:  24900.0
# Quantile 25:  7800.0
# IQR:  17100.0
# Upper bound:  33450.0
# Lower bound:  7800.0
# Max:  155000
# Min:  1
# Mean:  17763.516917293233
# Median:  13900.0
# === [bmw] ===
# Number of :  2967
# Quantile 75:  19373.5
# Quantile 25:  6995.0
# IQR:  12378.5
# Upper bound:  25562.75
# Lower bound:  6995.0
# Max:  95000
# Min:  1
# Mean:  14606.364678126054
# Median:  11995.0
# === [volkswagen] ===
# Number of :  2094
# Quantile 75:  11999.0
# Quantile 25:  5812.5
# IQR:  6186.5
# Upper bound:  15092.25
# Lower bound:  5812.5
# Max:  40000
# Min:  1
# Mean:  9707.958930276982
# Median:  8000.0
# === [mazda] ===
# Number of :  1189
# Quantile 75:  10995.0
# Quantile 25:  4950.0
# IQR:  6045.0
# Upper bound:  14017.5
# Lower bound:  4950.0
# Max:  36995
# Min:  1
# Mean:  8770.999158957107
# Median:  7000.0
# === [porsche] ===
# Number of :  334
# Quantile 75:  37500.0
# Quantile 25:  13481.25
# IQR:  24018.75
# Upper bound:  49509.375
# Lower bound:  13481.25
# Max:  150000
# Min:  1
# Mean:  28664.80239520958
# Median:  20925.0
# === [lexus] ===
# Number of :  1900
# Quantile 75:  25990.0
# Quantile 25:  8995.0
# IQR:  16995.0
# Upper bound:  34487.5
# Lower bound:  8995.0
# Max:  73995
# Min:  1
# Mean:  17949.546315789474
# Median:  16000.0
# === [ferrari] ===
# Number of :  17
# Quantile 75:  116899.0
# Quantile 25:  84965.0
# IQR:  31934.0
# Upper bound:  132866.0
# Lower bound:  84965.0
# Max:  169999
# Min:  1
# Mean:  95159.4705882353
# Median:  98900.0
# === [audi] ===
# Number of :  1179
# Quantile 75:  18837.5
# Quantile 25:  7850.0
# IQR:  10987.5
# Upper bound:  24331.25
# Lower bound:  7850.0
# Max:  106000
# Min:  1
# Mean:  14923.875318066157
# Median:  12500.0
# === [mitsubishi] ===
# Number of :  805
# Quantile 75:  23990.0
# Quantile 25:  5500.0
# IQR:  18490.0
# Upper bound:  33235.0
# Lower bound:  5500.0
# Max:  39900
# Min:  1
# Mean:  14072.767701863355
# Median:  10495.0
# === [infiniti] ===
# Number of :  1289
# Quantile 75:  27990.0
# Quantile 25:  9000.0
# IQR:  18990.0
# Upper bound:  37485.0
# Lower bound:  9000.0
# Max:  52000
# Min:  1
# Mean:  19436.188518231185
# Median:  19990.0
# === [kia] ===
# Number of :  1824
# Quantile 75:  12900.0
# Quantile 25:  5900.0
# IQR:  7000.0
# Upper bound:  16400.0
# Lower bound:  5900.0
# Max:  42900
# Min:  85
# Mean:  9818.245614035088
# Median:  8495.0
# === [hyundai] ===
# Number of :  2362
# Quantile 75:  12388.0
# Quantile 25:  5500.0
# IQR:  6888.0
# Upper bound:  15832.0
# Lower bound:  5500.0
# Max:  45590
# Min:  1
# Mean:  9471.15368331922
# Median:  7999.0
# === [fiat] ===
# Number of :  162
# Quantile 75:  10571.25
# Quantile 25:  5900.0
# IQR:  4671.25
# Upper bound:  12906.875
# Lower bound:  5900.0
# Max:  23000
# Min:  1
# Mean:  8563.62962962963
# Median:  7349.5
# === [cadillac] ===
# Number of :  1484
# Quantile 75:  19900.0
# Quantile 25:  6150.0
# IQR:  13750.0
# Upper bound:  26775.0
# Lower bound:  6150.0
# Max:  68297
# Min:  1
# Mean:  15599.886118598382
# Median:  11995.0
# === [rover] ===
# Number of :  383
# Quantile 75:  30725.0
# Quantile 25:  11500.0
# IQR:  19225.0
# Upper bound:  40337.5
# Lower bound:  11500.0
# Max:  129800
# Min:  1
# Mean:  23340.28459530026
# Median:  18999.0
# === [lincoln] ===
# Number of :  951
# Quantile 75:  21995.0
# Quantile 25:  6285.0
# IQR:  15710.0
# Upper bound:  29850.0
# Lower bound:  6285.0
# Max:  75850
# Min:  1
# Mean:  15572.305993690852
# Median:  11900.0
# === [jaguar] ===
# Number of :  358
# Quantile 75:  31990.0
# Quantile 25:  6990.0
# IQR:  25000.0
# Upper bound:  44490.0
# Lower bound:  6990.0
# Max:  150000
# Min:  199
# Mean:  20012.72067039106
# Median:  15450.0
# === [volvo] ===
# Number of :  670
# Quantile 75:  10998.75
# Quantile 25:  4362.5
# IQR:  6636.25
# Upper bound:  14316.875
# Lower bound:  4362.5
# Max:  144832
# Min:  1
# Mean:  9661.041791044776
# Median:  6950.0
# === [alfa-romeo] ===
# Number of :  44
# Quantile 75:  28549.25
# Quantile 25:  8875.0
# IQR:  19674.25
# Upper bound:  38386.375
# Lower bound:  8875.0
# Max:  62950
# Min:  1000
# Mean:  20198.090909090908
# Median:  26800.0
# === [acura] ===
# Number of :  1021
# Quantile 75:  19990.0
# Quantile 25:  6995.0
# IQR:  12995.0
# Upper bound:  26487.5
# Lower bound:  6995.0
# Max:  89000
# Min:  1
# Mean:  14607.445641527915
# Median:  11600.0
# === [subaru] ===
# Number of :  2392
# Quantile 75:  14912.5
# Quantile 25:  6500.0
# IQR:  8412.5
# Upper bound:  19118.75
# Lower bound:  6500.0
# Max:  195000
# Min:  1
# Mean:  11260.913879598662
# Median:  9500.0
# === [pontiac] ===
# Number of :  790
# Quantile 75:  8998.0
# Quantile 25:  3975.0
# IQR:  5023.0
# Upper bound:  11509.5
# Lower bound:  3975.0
# Max:  74000
# Min:  1
# Mean:  8634.684810126582
# Median:  5600.0
# === [saturn] ===
# Number of :  378
# Quantile 75:  5495.0
# Quantile 25:  3000.0
# IQR:  2495.0
# Upper bound:  6742.5
# Lower bound:  3000.0
# Max:  2000000
# Min:  500
# Mean:  10159.812169312168
# Median:  4200.0
# === [mini] ===
# Number of :  489
# Quantile 75:  10588.0
# Quantile 25:  5995.0
# IQR:  4593.0
# Upper bound:  12884.5
# Lower bound:  5995.0
# Max:  29000
# Min:  1
# Mean:  8979.018404907976
# Median:  7900.0
# === [buick] ===
# Number of :  1370
# Quantile 75:  15590.0
# Quantile 25:  4900.0
# IQR:  10690.0
# Upper bound:  20935.0
# Lower bound:  4900.0
# Max:  123456789
# Min:  21
# Mean:  102460.26642335767
# Median:  8995.0
# === [tesla] ===
# Number of :  38
# Quantile 75:  54750.0
# Quantile 25:  32999.25
# IQR:  21750.75
# Upper bound:  65625.375
# Lower bound:  32999.25
# Max:  84999
# Min:  1
# Mean:  43237.97368421053
# Median:  42000.0
# === [harley-davidson] ===
# Number of :  13
# Quantile 75:  19995.0
# Quantile 25:  14980.0
# IQR:  5015.0
# Upper bound:  22502.5
# Lower bound:  14980.0
# Max:  25950
# Min:  11250
# Mean:  17550.69230769231
# Median:  18000.0
# === [mercury] ===
# Number of :  427
# Quantile 75:  6788.0
# Quantile 25:  3000.0
# IQR:  3788.0
# Upper bound:  8682.0
# Lower bound:  3000.0
# Max:  60000
# Min:  1
# Mean:  5779.419203747073
# Median:  4400.0
# === [datsun] ===
# Number of :  18
# Quantile 75:  19162.5
# Quantile 25:  8995.0
# IQR:  10167.5
# Upper bound:  24246.25
# Lower bound:  8995.0
# Max:  26500
# Min:  1
# Mean:  14280.055555555555
# Median:  16950.0
# === [land rover] ===
# Number of :  8
# Quantile 75:  19498.75
# Quantile 25:  6371.25
# IQR:  13127.5
# Upper bound:  26062.5
# Lower bound:  6371.25
# Max:  55000
# Min:  3950
# Mean:  18116.875
# Median:  8247.5
# === [aston-martin] ===
# Number of :  3
# Quantile 75:  47497.5
# Quantile 25:  37947.5
# IQR:  9550.0
# Upper bound:  52272.5
# Lower bound:  37947.5
# Max:  52000
# Min:  32900
# Mean:  42631.666666666664
# Median:  42995.0
#        manufacturer                model          id  price    year  \
# 0              ford             -150 xlt  7312098448  20997  2014.0
# 1              ford  /vmi conversion van  7316387772  18500  2013.0
# 2              ford                  150  7302231495  29988  2015.0
# 3              ford              150 xlt  7313515244  21900  2014.0
# 4              ford                  250  7316861283   8200  1997.0
# ...             ...                  ...         ...    ...     ...
# 61527    land rover           freelander  7310494602   6995  2003.0
# 61528    land rover                  lr2  7312512367   8500  2008.0
# 61529    land rover                  lr2  7314020640   7995  2010.0
# 61530  aston-martin           martin db9  7316465896  42995  2006.0
# 61531  aston-martin        martin rapide  7304661436  52000  2010.0
#
#        condition    cylinders fuel  odometer transmission drive         type  \
# 0       like new  8 cylinders  gas  145000.0    automatic   4wd        truck
# 1      excellent  8 cylinders  gas   47362.0    automatic   rwd          van
# 2       like new  6 cylinders  gas   95000.0    automatic   4wd        truck
# 3      excellent  8 cylinders  gas   94942.0    automatic   rwd       pickup
# 4           good  8 cylinders  gas  177000.0        other   4wd        truck
# ...          ...          ...  ...       ...          ...   ...          ...
# 61527       good  6 cylinders  gas  112466.0    automatic   4wd          SUV
# 61528       good  6 cylinders  gas  144563.0    automatic   4wd          SUV
# 61529   like new  6 cylinders  gas  139465.0    automatic   4wd          SUV
# 61530   like new        other  gas   39648.0    automatic   rwd  convertible
# 61531   like new        other  gas   29970.0    automatic   rwd        sedan
#
#       paint_color
# 0          silver
# 1           other
# 2           other
# 3           other
# 4           other
# ...           ...
# 61527       other
# 61528      silver
# 61529       other
# 61530      silver
# 61531       other
#
# [61532 rows x 13 columns]

# %%
show_series(cleaned_2, 'price')
# Out:
# ========== [ INFO ] ==========
# Column:  price
# Number of unique values:  61532
# Max value:  120000
# Min value:  3000
# Mean value:  17004.460752128973
# Median value:  14000.0
# 25% percentile:  9498.75
# 75% percentile:  23000.0

# %%
df = cleaned_2

# %% [markdown]
# ## categorical to numeric
# - 브랜드별, 모델별 평균 가격을 랭크로 바꿔서 구하긴 했는데, 이상하면 그냥 제외하고 진행해도 돼!

# %% [markdown]
# ### 제조사, 모델 수치화 (선택)
# - 제조사 : 가격 평균을 순위화하여 구함
# - 모델 : 해당 브랜드 내에서의 평균 가격 순위를 정규화 한 값 + 브랜드 순위

# %%
df['count'] = 1
man_model_map_1 = pd.DataFrame(df.groupby(['manufacturer']).sum()[['count','price']])
man_model_map_1['price'] = round(man_model_map_1['price']/man_model_map_1['count'] ,2)
man_model_map_1.reset_index(inplace= True)
man_model_map_1 = man_model_map_1.sort_values('price', ascending=False)
man_model_map_1.reset_index(inplace= True, drop = True)
man_model_map_1['brand_id'] = man_model_map_1.index.tolist()
man_model_map_1['brand_id'] = man_model_map_1['brand_id'].apply(lambda x: len(man_model_map_1)-x)

man_model_map_1
# Out:
#        manufacturer  count      price  brand_id
# 0           ferrari     12  106421.75        41
# 1      aston-martin      2   47497.50        40
# 2             tesla     24   47001.00        39
# 3               ram   2269   31239.78        38
# 4               gmc   2719   27686.58        37
# 5           porsche    199   25942.97        36
# 6        alfa-romeo     32   24159.88        35
# 7             rover    238   22687.03        34
# 8          infiniti    883   22469.11        33
# 9            jaguar    255   22204.16        32
# 10             jeep   3342   21794.25        31
# 11        chevrolet   9967   21202.27        30
# 12            lexus   1305   20103.42        29
# 13             ford  10784   18623.10        28
# 14  harley-davidson      9   18606.56        27
# 15           datsun     13   16772.31        26
# 16    mercedes-benz   1585   16600.75        25
# 17       mitsubishi    556   15958.12        24
# 18          lincoln    588   14844.97        23
# 19           toyota   4532   14330.45        22
# 20             audi    712   14136.26        21
# 21            acura    603   14050.84        20
# 22              bmw   1764   13747.25        19
# 23         cadillac    851   13648.94        18
# 24            dodge   1966   13119.03        17
# 25           nissan   3174   11497.75        16
# 26           subaru   1555   11465.78        15
# 27            buick    796   10471.76        14
# 28              kia   1145    9830.94        13
# 29            honda   3403    9826.38        12
# 30       volkswagen   1283    9446.41        11
# 31          hyundai   1451    9354.89        10
# 32         chrysler   1086    8914.68         9
# 33             mini    286    8516.08         8
# 34       land rover      4    8372.50         7
# 35            mazda    711    8308.26         6
# 36             fiat     98    8214.55         5
# 37            volvo    386    7972.24         4
# 38          pontiac    439    6148.92         3
# 39          mercury    272    5153.47         2
# 40           saturn    233    4562.82         1

# %%
maptable = man_model_map_1[['manufacturer','brand_id']]
df = df.merge(maptable, on='manufacturer', how='left')
df
# Out:
#        manufacturer                model          id  price    year  \
# 0              ford             -150 xlt  7312098448  20997  2014.0
# 1              ford  /vmi conversion van  7316387772  18500  2013.0
# 2              ford                  150  7302231495  29988  2015.0
# 3              ford              150 xlt  7313515244  21900  2014.0
# 4              ford                  250  7316861283   8200  1997.0
# ...             ...                  ...         ...    ...     ...
# 61527    land rover           freelander  7310494602   6995  2003.0
# 61528    land rover                  lr2  7312512367   8500  2008.0
# 61529    land rover                  lr2  7314020640   7995  2010.0
# 61530  aston-martin           martin db9  7316465896  42995  2006.0
# 61531  aston-martin        martin rapide  7304661436  52000  2010.0
#
#        condition    cylinders fuel  odometer transmission drive         type  \
# 0       like new  8 cylinders  gas  145000.0    automatic   4wd        truck
# 1      excellent  8 cylinders  gas   47362.0    automatic   rwd          van
# 2       like new  6 cylinders  gas   95000.0    automatic   4wd        truck
# 3      excellent  8 cylinders  gas   94942.0    automatic   rwd       pickup
# 4           good  8 cylinders  gas  177000.0        other   4wd        truck
# ...          ...          ...  ...       ...          ...   ...          ...
# 61527       good  6 cylinders  gas  112466.0    automatic   4wd          SUV
# 61528       good  6 cylinders  gas  144563.0    automatic   4wd          SUV
# 61529   like new  6 cylinders  gas  139465.0    automatic   4wd          SUV
# 61530   like new        other  gas   39648.0    automatic   rwd  convertible
# 61531   like new        other  gas   29970.0    automatic   rwd        sedan
#
#       paint_color  count  brand_id
# 0          silver      1        28
# 1           other      1        28
# 2           other      1        28
# 3           other      1        28
# 4           other      1        28
# ...           ...    ...       ...
# 61527       other      1         7
# 61528      silver      1         7
# 61529       other      1         7
# 61530      silver      1        40
# 61531       other      1        40
#
# [61532 rows x 15 columns]

# %%
df['count'] = 1
man_model_map_2 = pd.DataFrame(df.groupby(['manufacturer','model']).sum()[['count','price']])
man_model_map_2['price'] = round(man_model_map_2['price']/man_model_map_2['count'] ,2)
man_model_map_2.reset_index(inplace= True)
man_model_map_2 = man_model_map_2.merge(maptable, on='manufacturer', how='left')
new_df = []
mans = man_model_map_2['manufacturer'].unique().tolist()
for man in mans:
    targ = man_model_map_2[man_model_map_2['manufacturer'] == man]
    targ.reset_index(inplace=True, drop = True)
    targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
    targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
    targ.reset_index(inplace= True, drop = True)
    new_df.append(targ)
new_df = pd.concat(new_df)
new_df.reset_index(inplace= True, drop = True)
new_df['model_id'] = new_df['model_id']+new_df['brand_id']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] =rankdata(targ['price'], method='dense')/len(targ)*0.9
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\1426454938.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targ['model_id'] = targ['model_id'].apply(lambda x: round(x,2))

# %%
model_maptable = new_df[['manufacturer','model','model_id']]
df = df.merge(model_maptable, on=['manufacturer','model'], how='left')
df
# Out:
#        manufacturer                model          id  price    year  \
# 0              ford             -150 xlt  7312098448  20997  2014.0
# 1              ford  /vmi conversion van  7316387772  18500  2013.0
# 2              ford                  150  7302231495  29988  2015.0
# 3              ford              150 xlt  7313515244  21900  2014.0
# 4              ford                  250  7316861283   8200  1997.0
# ...             ...                  ...         ...    ...     ...
# 61527    land rover           freelander  7310494602   6995  2003.0
# 61528    land rover                  lr2  7312512367   8500  2008.0
# 61529    land rover                  lr2  7314020640   7995  2010.0
# 61530  aston-martin           martin db9  7316465896  42995  2006.0
# 61531  aston-martin        martin rapide  7304661436  52000  2010.0
#
#        condition    cylinders fuel  odometer transmission drive         type  \
# 0       like new  8 cylinders  gas  145000.0    automatic   4wd        truck
# 1      excellent  8 cylinders  gas   47362.0    automatic   rwd          van
# 2       like new  6 cylinders  gas   95000.0    automatic   4wd        truck
# 3      excellent  8 cylinders  gas   94942.0    automatic   rwd       pickup
# 4           good  8 cylinders  gas  177000.0        other   4wd        truck
# ...          ...          ...  ...       ...          ...   ...          ...
# 61527       good  6 cylinders  gas  112466.0    automatic   4wd          SUV
# 61528       good  6 cylinders  gas  144563.0    automatic   4wd          SUV
# 61529   like new  6 cylinders  gas  139465.0    automatic   4wd          SUV
# 61530   like new        other  gas   39648.0    automatic   rwd  convertible
# 61531   like new        other  gas   29970.0    automatic   rwd        sedan
#
#       paint_color  count  brand_id  model_id
# 0          silver      1        28     28.39
# 1           other      1        28     28.33
# 2           other      1        28     28.53
# 3           other      1        28     28.40
# 4           other      1        28     28.02
# ...           ...    ...       ...       ...
# 61527       other      1         7      7.30
# 61528      silver      1         7      7.60
# 61529       other      1         7      7.60
# 61530      silver      1        40     40.45
# 61531       other      1        40     40.90
#
# [61532 rows x 16 columns]

# %% [markdown]
# ### 원핫인코딩 및 정규화
# - 뒤의 단계에서 컨디션, 드라이브, 타입 등의 원핫백터들을 PCA를 통해 한 차원의 백터값으로 축소

# %%
df = pd.get_dummies(df, columns = ['condition','drive','type','cylinders','fuel','transmission','paint_color'])
df = df.replace(True,1).replace(False,0)
df
# Out:
#        manufacturer                model          id  price    year  odometer  \
# 0              ford             -150 xlt  7312098448  20997  2014.0  145000.0
# 1              ford  /vmi conversion van  7316387772  18500  2013.0   47362.0
# 2              ford                  150  7302231495  29988  2015.0   95000.0
# 3              ford              150 xlt  7313515244  21900  2014.0   94942.0
# 4              ford                  250  7316861283   8200  1997.0  177000.0
# ...             ...                  ...         ...    ...     ...       ...
# 61527    land rover           freelander  7310494602   6995  2003.0  112466.0
# 61528    land rover                  lr2  7312512367   8500  2008.0  144563.0
# 61529    land rover                  lr2  7314020640   7995  2010.0  139465.0
# 61530  aston-martin           martin db9  7316465896  42995  2006.0   39648.0
# 61531  aston-martin        martin rapide  7304661436  52000  2010.0   29970.0
#
#        count  brand_id  model_id  condition_excellent  ...  \
# 0          1        28     28.39                    0  ...
# 1          1        28     28.33                    1  ...
# 2          1        28     28.53                    0  ...
# 3          1        28     28.40                    1  ...
# 4          1        28     28.02                    0  ...
# ...      ...       ...       ...                  ...  ...
# 61527      1         7      7.30                    0  ...
# 61528      1         7      7.60                    0  ...
# 61529      1         7      7.60                    0  ...
# 61530      1        40     40.45                    0  ...
# 61531      1        40     40.90                    0  ...
#
#        cylinders_6 cylinders  cylinders_8 cylinders  cylinders_other  \
# 0                          0                      1                0
# 1                          0                      1                0
# 2                          1                      0                0
# 3                          0                      1                0
# 4                          0                      1                0
# ...                      ...                    ...              ...
# 61527                      1                      0                0
# 61528                      1                      0                0
# 61529                      1                      0                0
# 61530                      0                      0                1
# 61531                      0                      0                1
#
#        fuel_gas  fuel_other  transmission_automatic  transmission_other  \
# 0             1           0                       1                   0
# 1             1           0                       1                   0
# 2             1           0                       1                   0
# 3             1           0                       1                   0
# 4             1           0                       0                   1
# ...         ...         ...                     ...                 ...
# 61527         1           0                       1                   0
# 61528         1           0                       1                   0
# 61529         1           0                       1                   0
# 61530         1           0                       1                   0
# 61531         1           0                       1                   0
#
#        paint_color_black  paint_color_other  paint_color_silver
# 0                      0                  0                   1
# 1                      0                  1                   0
# 2                      0                  1                   0
# 3                      0                  1                   0
# 4                      0                  1                   0
# ...                  ...                ...                 ...
# 61527                  0                  1                   0
# 61528                  0                  0                   1
# 61529                  0                  1                   0
# 61530                  0                  0                   1
# 61531                  0                  1                   0
#
# [61532 rows x 42 columns]

# %%
colist = [ 'price', 'year', 'odometer', 
       'brand_id', 'model_id','condition_excellent', 'condition_fair',
       'condition_good', 'condition_like new', 'condition_new',
       'condition_salvage', 'drive_4wd', 'drive_fwd', 'drive_rwd', 'type_SUV',
       'type_bus', 'type_convertible', 'type_coupe', 'type_hatchback',
       'type_mini-van', 'type_offroad', 'type_other', 'type_pickup',
       'type_sedan', 'type_truck', 'type_van', 'type_wagon',
       'cylinders_4 cylinders', 'cylinders_6 cylinders',
       'cylinders_8 cylinders', 'cylinders_other', 'fuel_gas', 'fuel_other',
       'transmission_automatic', 'transmission_other', 'paint_color_black',
       'paint_color_other', 'paint_color_silver']
df_set = df[colist]
df_set
# Out:
#        price    year  odometer  brand_id  model_id  condition_excellent  \
# 0      20997  2014.0  145000.0        28     28.39                    0
# 1      18500  2013.0   47362.0        28     28.33                    1
# 2      29988  2015.0   95000.0        28     28.53                    0
# 3      21900  2014.0   94942.0        28     28.40                    1
# 4       8200  1997.0  177000.0        28     28.02                    0
# ...      ...     ...       ...       ...       ...                  ...
# 61527   6995  2003.0  112466.0         7      7.30                    0
# 61528   8500  2008.0  144563.0         7      7.60                    0
# 61529   7995  2010.0  139465.0         7      7.60                    0
# 61530  42995  2006.0   39648.0        40     40.45                    0
# 61531  52000  2010.0   29970.0        40     40.90                    0
#
#        condition_fair  condition_good  condition_like new  condition_new  ...  \
# 0                   0               0                   1              0  ...
# 1                   0               0                   0              0  ...
# 2                   0               0                   1              0  ...
# 3                   0               0                   0              0  ...
# 4                   0               1                   0              0  ...
# ...               ...             ...                 ...            ...  ...
# 61527               0               1                   0              0  ...
# 61528               0               1                   0              0  ...
# 61529               0               0                   1              0  ...
# 61530               0               0                   1              0  ...
# 61531               0               0                   1              0  ...
#
#        cylinders_6 cylinders  cylinders_8 cylinders  cylinders_other  \
# 0                          0                      1                0
# 1                          0                      1                0
# 2                          1                      0                0
# 3                          0                      1                0
# 4                          0                      1                0
# ...                      ...                    ...              ...
# 61527                      1                      0                0
# 61528                      1                      0                0
# 61529                      1                      0                0
# 61530                      0                      0                1
# 61531                      0                      0                1
#
#        fuel_gas  fuel_other  transmission_automatic  transmission_other  \
# 0             1           0                       1                   0
# 1             1           0                       1                   0
# 2             1           0                       1                   0
# 3             1           0                       1                   0
# 4             1           0                       0                   1
# ...         ...         ...                     ...                 ...
# 61527         1           0                       1                   0
# 61528         1           0                       1                   0
# 61529         1           0                       1                   0
# 61530         1           0                       1                   0
# 61531         1           0                       1                   0
#
#        paint_color_black  paint_color_other  paint_color_silver
# 0                      0                  0                   1
# 1                      0                  1                   0
# 2                      0                  1                   0
# 3                      0                  1                   0
# 4                      0                  1                   0
# ...                  ...                ...                 ...
# 61527                  0                  1                   0
# 61528                  0                  0                   1
# 61529                  0                  1                   0
# 61530                  0                  0                   1
# 61531                  0                  1                   0
#
# [61532 rows x 38 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() # StandardScaler 클래스 생성
scaler.fit(df_set) # 표준화를 수행 함수 생성
transformed_X = scaler.transform(df_set) # 표준화 수행

# %%
df_set = pd.DataFrame(transformed_X)
df_set.columns = colist
df_set
# Out:
#           price      year  odometer  brand_id  model_id  condition_excellent  \
# 0      0.426474  0.366351  1.126476  0.506026  0.507541            -1.017179
# 1      0.159750  0.247943 -1.046962  0.506026  0.500695             0.983111
# 2      1.386873  0.484758  0.013468  0.506026  0.523516            -1.017179
# 3      0.522931  0.366351  0.012177  0.506026  0.508682             0.983111
# 4     -0.940473 -1.646577  1.838801  0.506026  0.465322            -1.017179
# ...         ...       ...       ...       ...       ...                  ...
# 61527 -1.069188 -0.936132  0.402264 -1.894809 -1.898967            -1.017179
# 61528 -0.908427 -0.344094  1.116748 -1.894809 -1.864735            -1.017179
# 61529 -0.962370 -0.107279  1.003266 -1.894809 -1.864735            -1.017179
# 61530  2.776251 -0.580909 -1.218676  1.877931  1.883667            -1.017179
# 61531  3.738145 -0.107279 -1.434110  1.877931  1.935015            -1.017179
#
#        condition_fair  condition_good  condition_like new  condition_new  ...  \
# 0           -0.072869       -0.762358            2.773037      -0.052945  ...
# 1           -0.072869       -0.762358           -0.360615      -0.052945  ...
# 2           -0.072869       -0.762358            2.773037      -0.052945  ...
# 3           -0.072869       -0.762358           -0.360615      -0.052945  ...
# 4           -0.072869        1.311720           -0.360615      -0.052945  ...
# ...               ...             ...                 ...            ...  ...
# 61527       -0.072869        1.311720           -0.360615      -0.052945  ...
# 61528       -0.072869        1.311720           -0.360615      -0.052945  ...
# 61529       -0.072869       -0.762358            2.773037      -0.052945  ...
# 61530       -0.072869       -0.762358            2.773037      -0.052945  ...
# 61531       -0.072869       -0.762358            2.773037      -0.052945  ...
#
#        cylinders_6 cylinders  cylinders_8 cylinders  cylinders_other  \
# 0                  -0.761000               1.560771        -0.138372
# 1                  -0.761000               1.560771        -0.138372
# 2                   1.314061              -0.640709        -0.138372
# 3                  -0.761000               1.560771        -0.138372
# 4                  -0.761000               1.560771        -0.138372
# ...                      ...                    ...              ...
# 61527               1.314061              -0.640709        -0.138372
# 61528               1.314061              -0.640709        -0.138372
# 61529               1.314061              -0.640709        -0.138372
# 61530              -0.761000              -0.640709         7.226920
# 61531              -0.761000              -0.640709         7.226920
#
#        fuel_gas  fuel_other  transmission_automatic  transmission_other  \
# 0      0.290316   -0.290316                0.446053           -0.446053
# 1      0.290316   -0.290316                0.446053           -0.446053
# 2      0.290316   -0.290316                0.446053           -0.446053
# 3      0.290316   -0.290316                0.446053           -0.446053
# 4      0.290316   -0.290316               -2.241885            2.241885
# ...         ...         ...                     ...                 ...
# 61527  0.290316   -0.290316                0.446053           -0.446053
# 61528  0.290316   -0.290316                0.446053           -0.446053
# 61529  0.290316   -0.290316                0.446053           -0.446053
# 61530  0.290316   -0.290316                0.446053           -0.446053
# 61531  0.290316   -0.290316                0.446053           -0.446053
#
#        paint_color_black  paint_color_other  paint_color_silver
# 0              -0.498872          -1.385621            2.446128
# 1              -0.498872           0.721698           -0.408809
# 2              -0.498872           0.721698           -0.408809
# 3              -0.498872           0.721698           -0.408809
# 4              -0.498872           0.721698           -0.408809
# ...                  ...                ...                 ...
# 61527          -0.498872           0.721698           -0.408809
# 61528          -0.498872          -1.385621            2.446128
# 61529          -0.498872           0.721698           -0.408809
# 61530          -0.498872          -1.385621            2.446128
# 61531          -0.498872           0.721698           -0.408809
#
# [61532 rows x 38 columns]

# %% [markdown]
# # 진행중인 부분!

# %% [markdown]
# ## Feature Extraction
# - 본격적인 클러스터 분석 이전, 가격에 영향을 미치는 주요 피쳐 선정

# %%
heat = df_set.corr()

sns.clustermap(heat, 
               annot = False,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

# %%
heat['price'].sort_values(ascending=False)
# Out:
# price                     1.000000
# model_id                  0.621497
# brand_id                  0.611746
# transmission_other        0.371117
# cylinders_8 cylinders     0.331142
# type_pickup               0.330492
# drive_4wd                 0.305360
# year                      0.240033
# type_truck                0.232607
# condition_good            0.205644
# fuel_other                0.201708
# type_other                0.181029
# drive_rwd                 0.110957
# cylinders_6 cylinders     0.078758
# paint_color_black         0.032234
# type_van                  0.027583
# type_coupe                0.026892
# paint_color_other         0.024953
# condition_like new        0.012273
# type_offroad              0.011808
# type_bus                 -0.002037
# condition_new            -0.005600
# type_convertible         -0.011841
# condition_salvage        -0.016771
# cylinders_other          -0.029344
# condition_fair           -0.055375
# paint_color_silver       -0.070567
# type_wagon               -0.080244
# type_SUV                 -0.082109
# type_mini-van            -0.090326
# type_hatchback           -0.140034
# condition_excellent      -0.196615
# fuel_gas                 -0.201708
# type_sedan               -0.316401
# transmission_automatic   -0.371117
# cylinders_4 cylinders    -0.394169
# drive_fwd                -0.422941
# odometer                 -0.465045
# Name: price, dtype: float64

# %%
heat[(heat['price'] > 0.3) | (heat['price'] < -0.3) ]
# Out:
#                            price      year  odometer  brand_id  model_id  \
# price                   1.000000  0.240033 -0.465045  0.611746  0.621497
# odometer               -0.465045 -0.155343  1.000000 -0.181860 -0.186653
# brand_id                0.611746  0.058455 -0.181860  1.000000  0.999820
# model_id                0.621497  0.061456 -0.186653  0.999820  1.000000
# drive_4wd               0.305360  0.119600  0.095042  0.306373  0.309806
# drive_fwd              -0.422941  0.142386 -0.017115 -0.446799 -0.451379
# type_pickup             0.330492  0.042150 -0.098218  0.308087  0.310852
# type_sedan             -0.316401  0.075546 -0.049597 -0.331299 -0.334645
# cylinders_4 cylinders  -0.394169  0.153412 -0.032427 -0.420705 -0.424953
# cylinders_8 cylinders   0.331142 -0.246437  0.067263  0.397469  0.398868
# transmission_automatic -0.371117  0.024157  0.347444 -0.199760 -0.206207
# transmission_other      0.371117 -0.024157 -0.347444  0.199760  0.206207
#
#                         condition_excellent  condition_fair  condition_good  \
# price                             -0.196615       -0.055375        0.205644
# odometer                           0.161985        0.037151       -0.118587
# brand_id                          -0.128854       -0.021493        0.141570
# model_id                          -0.132262       -0.021831        0.145747
# drive_4wd                         -0.007318       -0.007268        0.024815
# drive_fwd                          0.072443       -0.013008       -0.097760
# type_pickup                       -0.094702       -0.001296        0.146228
# type_sedan                         0.063348       -0.015644       -0.089318
# cylinders_4 cylinders              0.119494       -0.015874       -0.150906
# cylinders_8 cylinders             -0.072747        0.036237        0.095477
# transmission_automatic             0.269519       -0.006670       -0.345542
# transmission_other                -0.269519        0.006670        0.345542
#
#                         condition_like new  condition_new  ...  \
# price                             0.012273      -0.005600  ...
# odometer                         -0.082590      -0.000318  ...
# brand_id                         -0.005736      -0.005338  ...
# model_id                         -0.006592      -0.005508  ...
# drive_4wd                        -0.024161      -0.001403  ...
# drive_fwd                         0.036361       0.000518  ...
# type_pickup                      -0.070767      -0.006749  ...
# type_sedan                        0.038008       0.002690  ...
# cylinders_4 cylinders             0.042536       0.005506  ...
# cylinders_8 cylinders            -0.038660       0.004027  ...
# transmission_automatic            0.100212       0.006241  ...
# transmission_other               -0.100212      -0.006241  ...
#
#                         cylinders_6 cylinders  cylinders_8 cylinders  \
# price                                0.078758               0.331142
# odometer                            -0.033848               0.067263
# brand_id                             0.050654               0.397469
# model_id                             0.053517               0.398868
# drive_4wd                            0.106124               0.148839
# drive_fwd                           -0.083092              -0.417502
# type_pickup                         -0.009818               0.252406
# type_sedan                          -0.076694              -0.269258
# cylinders_4 cylinders               -0.526174              -0.443002
# cylinders_8 cylinders               -0.487579               1.000000
# transmission_automatic              -0.112515              -0.036471
# transmission_other                   0.112515               0.036471
#
#                         cylinders_other  fuel_gas  fuel_other  \
# price                         -0.029344 -0.201708    0.201708
# odometer                       0.006832 -0.051665    0.051665
# brand_id                      -0.060066 -0.151571    0.151571
# model_id                      -0.060276 -0.153261    0.153261
# drive_4wd                     -0.043025 -0.055499    0.055499
# drive_fwd                      0.020470  0.060447   -0.060447
# type_pickup                   -0.024868 -0.104046    0.104046
# type_sedan                     0.009329  0.085387   -0.085387
# cylinders_4 cylinders         -0.095674  0.057873   -0.057873
# cylinders_8 cylinders         -0.088656 -0.101418    0.101418
# transmission_automatic         0.017321  0.027455   -0.027455
# transmission_other            -0.017321 -0.027455    0.027455
#
#                         transmission_automatic  transmission_other  \
# price                                -0.371117            0.371117
# odometer                              0.347444           -0.347444
# brand_id                             -0.199760            0.199760
# model_id                             -0.206207            0.206207
# drive_4wd                            -0.056584            0.056584
# drive_fwd                             0.145754           -0.145754
# type_pickup                          -0.227908            0.227908
# type_sedan                            0.133072           -0.133072
# cylinders_4 cylinders                 0.146299           -0.146299
# cylinders_8 cylinders                -0.036471            0.036471
# transmission_automatic                1.000000           -1.000000
# transmission_other                   -1.000000            1.000000
#
#                         paint_color_black  paint_color_other  \
# price                            0.032234           0.024953
# odometer                        -0.020360           0.009306
# brand_id                         0.035554           0.028602
# model_id                         0.036333           0.028362
# drive_4wd                        0.055041          -0.039111
# drive_fwd                       -0.026654          -0.029369
# type_pickup                      0.015570           0.011156
# type_sedan                       0.029258          -0.076966
# cylinders_4 cylinders           -0.022616          -0.016920
# cylinders_8 cylinders            0.009254           0.057677
# transmission_automatic          -0.032716           0.018781
# transmission_other               0.032716          -0.018781
#
#                         paint_color_silver
# price                            -0.070567
# odometer                          0.010612
# brand_id                         -0.079295
# model_id                         -0.079860
# drive_4wd                        -0.009784
# drive_fwd                         0.070185
# type_pickup                      -0.032871
# type_sedan                        0.070904
# cylinders_4 cylinders             0.048715
# cylinders_8 cylinders            -0.088693
# transmission_automatic            0.011867
# transmission_other               -0.011867
#
# [12 rows x 38 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components= 1) # 주성분을 몇개로 할지 결정


pcad = df[['condition_excellent', 'condition_fair',
       'condition_good', 'condition_like new', 'condition_new',
       'condition_salvage', 'drive_4wd', 'drive_fwd', 'drive_rwd', 'type_SUV',
       'type_bus', 'type_convertible', 'type_coupe', 'type_hatchback',
       'type_mini-van', 'type_offroad', 'type_other', 'type_pickup',
       'type_sedan', 'type_truck', 'type_van', 'type_wagon',
       'cylinders_4 cylinders', 'cylinders_6 cylinders',
       'cylinders_8 cylinders', 'cylinders_other', 'fuel_gas', 'fuel_other',
       'transmission_automatic', 'transmission_other', 'paint_color_black',
       'paint_color_other', 'paint_color_silver']]

featureset =pcad

printcipalComponents = pca.fit_transform(featureset)
principalDf = pd.DataFrame(data=printcipalComponents, columns = ['pc1'])
principalDf
# Out:
#             pc1
# 0      0.632069
# 1      0.135642
# 2      0.548555
# 3      0.285557
# 4      1.444374
# ...         ...
# 61527  0.767095
# 61528  0.681383
# 61529  0.442787
# 61530  0.016956
# 61531 -0.222026
#
# [61532 rows x 1 columns]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.17641382])

# %%
ndf = df_set[['price', 'year', 'odometer','brand_id', 'model_id']]
ndf['total_category'] = principalDf['pc1']
ndf
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\2682734562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['total_category'] = principalDf['pc1']
#           price      year  odometer  brand_id  model_id  total_category
# 0      0.426474  0.366351  1.126476  0.506026  0.507541        0.632069
# 1      0.159750  0.247943 -1.046962  0.506026  0.500695        0.135642
# 2      1.386873  0.484758  0.013468  0.506026  0.523516        0.548555
# 3      0.522931  0.366351  0.012177  0.506026  0.508682        0.285557
# 4     -0.940473 -1.646577  1.838801  0.506026  0.465322        1.444374
# ...         ...       ...       ...       ...       ...             ...
# 61527 -1.069188 -0.936132  0.402264 -1.894809 -1.898967        0.767095
# 61528 -0.908427 -0.344094  1.116748 -1.894809 -1.864735        0.681383
# 61529 -0.962370 -0.107279  1.003266 -1.894809 -1.864735        0.442787
# 61530  2.776251 -0.580909 -1.218676  1.877931  1.883667        0.016956
# 61531  3.738145 -0.107279 -1.434110  1.877931  1.935015       -0.222026
#
# [61532 rows x 6 columns]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state=500)
cluster = kmeans.fit(ndf)
ndf['kmeans_cluster'] = cluster.labels_
ndf
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\user\AppData\Local\Temp\ipykernel_24556\2838207914.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['kmeans_cluster'] = cluster.labels_
#           price      year  odometer  brand_id  model_id  total_category  \
# 0      0.426474  0.366351  1.126476  0.506026  0.507541        0.632069
# 1      0.159750  0.247943 -1.046962  0.506026  0.500695        0.135642
# 2      1.386873  0.484758  0.013468  0.506026  0.523516        0.548555
# 3      0.522931  0.366351  0.012177  0.506026  0.508682        0.285557
# 4     -0.940473 -1.646577  1.838801  0.506026  0.465322        1.444374
# ...         ...       ...       ...       ...       ...             ...
# 61527 -1.069188 -0.936132  0.402264 -1.894809 -1.898967        0.767095
# 61528 -0.908427 -0.344094  1.116748 -1.894809 -1.864735        0.681383
# 61529 -0.962370 -0.107279  1.003266 -1.894809 -1.864735        0.442787
# 61530  2.776251 -0.580909 -1.218676  1.877931  1.883667        0.016956
# 61531  3.738145 -0.107279 -1.434110  1.877931  1.935015       -0.222026
#
#        kmeans_cluster
# 0                   2
# 1                   5
# 2                   5
# 3                   5
# 4                   9
# ...               ...
# 61527               0
# 61528               0
# 61529               0
# 61530               3
# 61531               3
#
# [61532 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(ndf)
principalDf = pd.DataFrame(data=principalComponents, columns = ['pc1', 'pc2'])
principalDf['cluster'] = ndf['kmeans_cluster']
axs = plt.subplots()
axs = sns.scatterplot(x='pc1', y='pc2', hue='cluster', data=principalDf)

# %%
ndf
# Out:
#           price      year  odometer  brand_id  model_id  total_category  \
# 0      0.426474  0.366351  1.126476  0.506026  0.507541        0.632069
# 1      0.159750  0.247943 -1.046962  0.506026  0.500695        0.135642
# 2      1.386873  0.484758  0.013468  0.506026  0.523516        0.548555
# 3      0.522931  0.366351  0.012177  0.506026  0.508682        0.285557
# 4     -0.940473 -1.646577  1.838801  0.506026  0.465322        1.444374
# ...         ...       ...       ...       ...       ...             ...
# 61527 -1.069188 -0.936132  0.402264 -1.894809 -1.898967        0.767095
# 61528 -0.908427 -0.344094  1.116748 -1.894809 -1.864735        0.681383
# 61529 -0.962370 -0.107279  1.003266 -1.894809 -1.864735        0.442787
# 61530  2.776251 -0.580909 -1.218676  1.877931  1.883667        0.016956
# 61531  3.738145 -0.107279 -1.434110  1.877931  1.935015       -0.222026
#
#        kmeans_cluster
# 0                   1
# 1                   3
# 2                   2
# 3                   3
# 4                   0
# ...               ...
# 61527               3
# 61528               3
# 61529               3
# 61530               2
# 61531               2
#
# [61532 rows x 7 columns]

# %%
# create model and predictio
from sklearn.cluster import DBSCAN
model = DBSCAN(min_samples=13)
#ndf.drop(['cluster'], axis=1, inplace=True)
dbscandf = ndf[['price', 'year', 'odometer','brand_id', 'model_id','total_category']]
predict = pd.DataFrame(model.fit_predict(dbscandf))
predict.columns=['predict']

# %%
dbscandf['cluster'] = predict['predict']
dbscandf
# Out:
#           price      year  odometer  brand_id  model_id  total_category  \
# 0      0.426474  0.366351  1.126476  0.506026  0.507541        0.632069
# 1      0.159750  0.247943 -1.046962  0.506026  0.500695        0.135642
# 2      1.386873  0.484758  0.013468  0.506026  0.523516        0.548555
# 3      0.522931  0.366351  0.012177  0.506026  0.508682        0.285557
# 4     -0.940473 -1.646577  1.838801  0.506026  0.465322        1.444374
# ...         ...       ...       ...       ...       ...             ...
# 61527 -1.069188 -0.936132  0.402264 -1.894809 -1.898967        0.767095
# 61528 -0.908427 -0.344094  1.116748 -1.894809 -1.864735        0.681383
# 61529 -0.962370 -0.107279  1.003266 -1.894809 -1.864735        0.442787
# 61530  2.776251 -0.580909 -1.218676  1.877931  1.883667        0.016956
# 61531  3.738145 -0.107279 -1.434110  1.877931  1.935015       -0.222026
#
#        cluster
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 61527        0
# 61528        0
# 61529        0
# 61530       -1
# 61531       -1
#
# [61532 rows x 7 columns]

# %%
dbscandf.groupby(['cluster']).count()
# Out:
#          price   year  odometer  brand_id  model_id  total_category
# cluster
# -1        2435   2435      2435      2435      2435            2435
#  0       58780  58780     58780     58780     58780           58780
#  1          17     17        17        17        17              17
#  2          20     20        20        20        20              20
#  3         146    146       146       146       146             146
#  4          20     20        20        20        20              20
#  5          22     22        22        22        22              22
#  6          20     20        20        20        20              20
#  7           9      9         9         9         9               9
#  8          27     27        27        27        27              27
#  9          36     36        36        36        36              36

# %%
principalDf['dbscan_cluster'] = dbscandf['cluster']
axs = plt.subplots()
axs = sns.scatterplot(x='pc1', y='pc2', hue='dbscan_cluster', data=principalDf)

# %%
year_odo = df_set[['year','odometer']]
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=30, random_state=0)
cluster = kmeans.fit(year_odo)
df_set['year_odo_cluster'] = cluster.labels_

kmeans = KMeans(n_clusters=30, random_state=0)
brand_model = df_set[['price','model_id']]
cluster = kmeans.fit(brand_model)
df_set['brand_model_cluster'] = cluster.labels_

df_set
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#           price      year  odometer  brand_id  model_id  condition_excellent  \
# 0      0.426474  0.366351  1.126476  0.506026  0.507541            -1.017179
# 1      0.159750  0.247943 -1.046962  0.506026  0.500695             0.983111
# 2      1.386873  0.484758  0.013468  0.506026  0.523516            -1.017179
# 3      0.522931  0.366351  0.012177  0.506026  0.508682             0.983111
# 4     -0.940473 -1.646577  1.838801  0.506026  0.465322            -1.017179
# ...         ...       ...       ...       ...       ...                  ...
# 61527 -1.069188 -0.936132  0.402264 -1.894809 -1.898967            -1.017179
# 61528 -0.908427 -0.344094  1.116748 -1.894809 -1.864735            -1.017179
# 61529 -0.962370 -0.107279  1.003266 -1.894809 -1.864735            -1.017179
# 61530  2.776251 -0.580909 -1.218676  1.877931  1.883667            -1.017179
# 61531  3.738145 -0.107279 -1.434110  1.877931  1.935015            -1.017179
#
#        condition_fair  condition_good  condition_like new  condition_new  ...  \
# 0           -0.072869       -0.762358            2.773037      -0.052945  ...
# 1           -0.072869       -0.762358           -0.360615      -0.052945  ...
# 2           -0.072869       -0.762358            2.773037      -0.052945  ...
# 3           -0.072869       -0.762358           -0.360615      -0.052945  ...
# 4           -0.072869        1.311720           -0.360615      -0.052945  ...
# ...               ...             ...                 ...            ...  ...
# 61527       -0.072869        1.311720           -0.360615      -0.052945  ...
# 61528       -0.072869        1.311720           -0.360615      -0.052945  ...
# 61529       -0.072869       -0.762358            2.773037      -0.052945  ...
# 61530       -0.072869       -0.762358            2.773037      -0.052945  ...
# 61531       -0.072869       -0.762358            2.773037      -0.052945  ...
#
#        paint_color_green  paint_color_grey  paint_color_orange  \
# 0              -0.152306         -0.356806           -0.072981
# 1              -0.152306         -0.356806           -0.072981
# 2              -0.152306         -0.356806           -0.072981
# 3              -0.152306          2.802641           -0.072981
# 4              -0.152306         -0.356806           -0.072981
# ...                  ...               ...                 ...
# 61527          -0.152306          2.802641           -0.072981
# 61528          -0.152306         -0.356806           -0.072981
# 61529          -0.152306         -0.356806           -0.072981
# 61530          -0.152306         -0.356806           -0.072981
# 61531          -0.152306          2.802641           -0.072981
#
#        paint_color_purple  paint_color_red  paint_color_silver  \
# 0               -0.047583        -0.345240            2.446128
# 1               -0.047583         2.896532           -0.408809
# 2               -0.047583        -0.345240           -0.408809
# 3               -0.047583        -0.345240           -0.408809
# 4               -0.047583        -0.345240           -0.408809
# ...                   ...              ...                 ...
# 61527           -0.047583        -0.345240           -0.408809
# 61528           -0.047583        -0.345240            2.446128
# 61529           -0.047583        -0.345240           -0.408809
# 61530           -0.047583        -0.345240            2.446128
# 61531           -0.047583        -0.345240           -0.408809
#
#        paint_color_white  paint_color_yellow  year_odo_cluster  \
# 0              -0.569493            -0.09133                 2
# 1              -0.569493            -0.09133                26
# 2               1.755947            -0.09133                 9
# 3              -0.569493            -0.09133                 9
# 4               1.755947            -0.09133                10
# ...                  ...                 ...               ...
# 61527          -0.569493            -0.09133                11
# 61528          -0.569493            -0.09133                19
# 61529           1.755947            -0.09133                21
# 61530          -0.569493            -0.09133                 6
# 61531          -0.569493            -0.09133                26
#
#        brand_model_cluster
# 0                        9
# 1                        9
# 2                        3
# 3                        9
# 4                       15
# ...                    ...
# 61527                    4
# 61528                    4
# 61529                    4
# 61530                   22
# 61531                   22
#
# [61532 rows x 57 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
axs = plt.subplots()
axs = sns.scatterplot(x='year', y='odometer', hue='year_odo_cluster', data=df_set)

# %%
axs = sns.scatterplot(x='model_id', y='price', hue='brand_model_cluster', data=df_set)

# %%
kmeans = KMeans(n_clusters=20, random_state=0)
brand_model = df_set[['year_odo_cluster','brand_model_cluster']]
cluster = kmeans.fit(brand_model)
df_set['total_cluster'] = cluster.labels_
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df_set
# Out:
#           price      year  odometer  brand_id  model_id  condition_excellent  \
# 0      0.426474  0.366351  1.126476  0.506026  0.507541            -1.017179
# 1      0.159750  0.247943 -1.046962  0.506026  0.500695             0.983111
# 2      1.386873  0.484758  0.013468  0.506026  0.523516            -1.017179
# 3      0.522931  0.366351  0.012177  0.506026  0.508682             0.983111
# 4     -0.940473 -1.646577  1.838801  0.506026  0.465322            -1.017179
# ...         ...       ...       ...       ...       ...                  ...
# 61527 -1.069188 -0.936132  0.402264 -1.894809 -1.898967            -1.017179
# 61528 -0.908427 -0.344094  1.116748 -1.894809 -1.864735            -1.017179
# 61529 -0.962370 -0.107279  1.003266 -1.894809 -1.864735            -1.017179
# 61530  2.776251 -0.580909 -1.218676  1.877931  1.883667            -1.017179
# 61531  3.738145 -0.107279 -1.434110  1.877931  1.935015            -1.017179
#
#        condition_fair  condition_good  condition_like new  condition_new  ...  \
# 0           -0.072869       -0.762358            2.773037      -0.052945  ...
# 1           -0.072869       -0.762358           -0.360615      -0.052945  ...
# 2           -0.072869       -0.762358            2.773037      -0.052945  ...
# 3           -0.072869       -0.762358           -0.360615      -0.052945  ...
# 4           -0.072869        1.311720           -0.360615      -0.052945  ...
# ...               ...             ...                 ...            ...  ...
# 61527       -0.072869        1.311720           -0.360615      -0.052945  ...
# 61528       -0.072869        1.311720           -0.360615      -0.052945  ...
# 61529       -0.072869       -0.762358            2.773037      -0.052945  ...
# 61530       -0.072869       -0.762358            2.773037      -0.052945  ...
# 61531       -0.072869       -0.762358            2.773037      -0.052945  ...
#
#        paint_color_grey  paint_color_orange  paint_color_purple  \
# 0             -0.356806           -0.072981           -0.047583
# 1             -0.356806           -0.072981           -0.047583
# 2             -0.356806           -0.072981           -0.047583
# 3              2.802641           -0.072981           -0.047583
# 4             -0.356806           -0.072981           -0.047583
# ...                 ...                 ...                 ...
# 61527          2.802641           -0.072981           -0.047583
# 61528         -0.356806           -0.072981           -0.047583
# 61529         -0.356806           -0.072981           -0.047583
# 61530         -0.356806           -0.072981           -0.047583
# 61531          2.802641           -0.072981           -0.047583
#
#        paint_color_red  paint_color_silver  paint_color_white  \
# 0            -0.345240            2.446128          -0.569493
# 1             2.896532           -0.408809          -0.569493
# 2            -0.345240           -0.408809           1.755947
# 3            -0.345240           -0.408809          -0.569493
# 4            -0.345240           -0.408809           1.755947
# ...                ...                 ...                ...
# 61527        -0.345240           -0.408809          -0.569493
# 61528        -0.345240            2.446128          -0.569493
# 61529        -0.345240           -0.408809           1.755947
# 61530        -0.345240            2.446128          -0.569493
# 61531        -0.345240           -0.408809          -0.569493
#
#        paint_color_yellow  year_odo_cluster  brand_model_cluster  \
# 0                -0.09133                 2                    9
# 1                -0.09133                26                    9
# 2                -0.09133                 9                    3
# 3                -0.09133                 9                    9
# 4                -0.09133                10                   15
# ...                   ...               ...                  ...
# 61527            -0.09133                11                    4
# 61528            -0.09133                19                    4
# 61529            -0.09133                21                    4
# 61530            -0.09133                 6                   22
# 61531            -0.09133                26                   22
#
#        total_cluster
# 0                 18
# 1                 10
# 2                 17
# 3                  2
# 4                 15
# ...              ...
# 61527             17
# 61528              0
# 61529              0
# 61530              7
# 61531              6
#
# [61532 rows x 58 columns]

# %%
axs = plt.subplots()
axs = sns.scatterplot(x='year_odo_cluster', y='price', hue='total_cluster', data=df_set)

# %%
df['total_cluster'] = df_set['total_cluster']
df
# Out:
#        manufacturer                model          id  price    year  odometer  \
# 0              ford             -150 xlt  7312098448  20997  2014.0  145000.0
# 1              ford  /vmi conversion van  7316387772  18500  2013.0   47362.0
# 2              ford                  150  7302231495  29988  2015.0   95000.0
# 3              ford              150 xlt  7313515244  21900  2014.0   94942.0
# 4              ford                  250  7316861283   8200  1997.0  177000.0
# ...             ...                  ...         ...    ...     ...       ...
# 61527    land rover           freelander  7310494602   6995  2003.0  112466.0
# 61528    land rover                  lr2  7312512367   8500  2008.0  144563.0
# 61529    land rover                  lr2  7314020640   7995  2010.0  139465.0
# 61530  aston-martin           martin db9  7316465896  42995  2006.0   39648.0
# 61531  aston-martin        martin rapide  7304661436  52000  2010.0   29970.0
#
#        count  brand_id  model_id  condition_excellent  ...  \
# 0          1        28     28.39                    0  ...
# 1          1        28     28.33                    1  ...
# 2          1        28     28.53                    0  ...
# 3          1        28     28.40                    1  ...
# 4          1        28     28.02                    0  ...
# ...      ...       ...       ...                  ...  ...
# 61527      1         7      7.30                    0  ...
# 61528      1         7      7.60                    0  ...
# 61529      1         7      7.60                    0  ...
# 61530      1        40     40.45                    0  ...
# 61531      1        40     40.90                    0  ...
#
#        paint_color_custom  paint_color_green  paint_color_grey  \
# 0                       0                  0                 0
# 1                       0                  0                 0
# 2                       0                  0                 0
# 3                       0                  0                 1
# 4                       0                  0                 0
# ...                   ...                ...               ...
# 61527                   0                  0                 1
# 61528                   0                  0                 0
# 61529                   0                  0                 0
# 61530                   0                  0                 0
# 61531                   0                  0                 1
#
#        paint_color_orange  paint_color_purple  paint_color_red  \
# 0                       0                   0                0
# 1                       0                   0                1
# 2                       0                   0                0
# 3                       0                   0                0
# 4                       0                   0                0
# ...                   ...                 ...              ...
# 61527                   0                   0                0
# 61528                   0                   0                0
# 61529                   0                   0                0
# 61530                   0                   0                0
# 61531                   0                   0                0
#
#        paint_color_silver  paint_color_white  paint_color_yellow  \
# 0                       1                  0                   0
# 1                       0                  0                   0
# 2                       0                  1                   0
# 3                       0                  0                   0
# 4                       0                  1                   0
# ...                   ...                ...                 ...
# 61527                   0                  0                   0
# 61528                   1                  0                   0
# 61529                   0                  1                   0
# 61530                   1                  0                   0
# 61531                   0                  0                   0
#
#        total_cluster
# 0                 18
# 1                 10
# 2                 17
# 3                  2
# 4                 15
# ...              ...
# 61527             17
# 61528              0
# 61529              0
# 61530              7
# 61531              6
#
# [61532 rows x 60 columns]

# %%
df[['price','odometer','total_cluster']].groupby(['total_cluster']).min()
# Out:
#                price  odometer
# total_cluster
# 0               5500   12000.0
# 1               3000   10275.0
# 2               5600   10230.0
# 3               3000   11000.0
# 4               4900   14700.0
# 5               5500   10700.0
# 6               3000   10450.0
# 7               4500   12343.0
# 8               4950   10600.0
# 9               5500   10369.0
# 10              4900   12198.0
# 11              5650   10600.0
# 12              3100   11600.0
# 13              5000   11061.0
# 14              5500   10750.0
# 15              4900   11111.0
# 16              4500   10700.0
# 17              5500   10400.0
# 18              5500   11950.0
# 19              3000   14000.0

# %%
df[['price','odometer','total_cluster']].groupby(['total_cluster']).max()
# Out:
#                 price  odometer
# total_cluster
# 0               39800  194500.0
# 1               59900  194328.0
# 2               42995  194402.0
# 3               45000  194525.0
# 4               42988  190000.0
# 5               33595  194454.0
# 6               52000  190000.0
# 7               54750  170000.0
# 8               35000  194667.0
# 9               40995  194595.0
# 10              39995  190000.0
# 11              31590  165546.0
# 12              36000  167707.0
# 13              38901  167000.0
# 14              31590  193000.0
# 15             120000  194664.0
# 16              45995  194126.0
# 17              31590  194000.0
# 18              39000  167333.0
# 19              63995  187000.0
